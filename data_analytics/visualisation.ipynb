# %% [markdown]
# VISUALIZATION
# - figure
# - axes
# - plot
# - pie
# - bar
# - scatter
# - hist
# - box
# - step
# - subplots

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
y = [21,344,12,321,32,21,43,1]
plt.plot(y)

# %%
plt.figure(figsize=(10,10))
plt.pie(y)
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,2))
plt.show()

# %%
t = np.arange(-3 * np.pi, 3 * np.pi, 0.2)
x = np.sin(t)
y = np.cos(t)
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,2))
ax[0].plot(t, x, 'r')
ax[1].bar(t, y)
plt.show()

# %%
x = [100,200,300,400,500,600,700,800,900,1000]
y = [23,45,1,34,65,2,2,46,34,56]
plt.plot(x,y, linewidth=2, color='green', marker='x', markersize=10, markerfacecolor='white', markeredgecolor='red', linestyle='--')
plt.show()

# %%
plt.plot(x, y, 'go--', linewidth=2,markersize=10, markerfacecolor='white', markeredgecolor='red',)
plt.title("Some graph showing something",
    fontdict={'fontsize':15,'fontweight':'light','color':'green'})
plt.xlabel("X axis ki values")
plt.ylabel("Y axis ki values", fontdict={'color':'red'})
plt.text(800,60,"This is serious")
plt.annotate("Peak value",xy=(500,65), xytext=(600, 40), 
    arrowprops=dict(facecolor='green', width=1))
plt.show()
